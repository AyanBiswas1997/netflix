# %%
import pandas as pd

# %%
data=pd.read_csv('netflix1.csv')

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data.median
# Out:
# <bound method DataFrame.median of      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
# ...

# %%
import numpy as np

# %%
print(data.dtypes)
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
data['type'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Movie
# 1       TV Show
# 2       TV Show
# 3         Movie
# 4         Movie
#          ...
# 8785    TV Show
# 8786    TV Show
# 8787    TV Show
# 8788    TV Show
# 8789    TV Show
# Name: type, Length: 8790, dtype: object>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,20))
sns.barplot(data=data,x=data['type'],y=data['release_year'])
plt.show()

# %%
 type_counts = data['type'].value_counts()
 plt.figure(figsize=(8, 6))
 sns.barplot(x=type_counts.index, y=type_counts.values,
 palette='Set2')
 y=type_counts.values,
 plt.title('Distribution of Content by Type')
 plt.xlabel('Type')
 plt.ylabel('Count')
 plt.show()

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
data.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
count=data['director'].value_counts()

# %%
plt.figure(figsize=(8,6))
sns.histplot(x=count.index,y=count.values,palette='set2')
y=count.values
plt.show()
# Out:
# C:\Users\AYAN\AppData\Local\Temp\ipykernel_1096\3363285558.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=count.index,y=count.values,palette='set2')
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
type_counts = data['type'].value_counts()
plt.pie(type_counts,labels=['TV Show','movie'],autopct='%.0f%%')
plt.show()

# %%
sns.scatterplot(data=data,x='release_year',y='rating',hue='rating')
# Out:
# <Axes: xlabel='release_year', ylabel='rating'>

# %%
for column in data:
    print(column)
# Out:
# show_id
# type
# title
# director
# country
# date_added
# release_year
# rating
# duration
# listed_in

# %%
data['rating'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-PG
# 4       TV-MA
#         ...
# 8785    TV-PG
# 8786    TV-Y7
# 8787    TV-PG
# 8788     TV-Y
# 8789    TV-Y7
# Name: rating, Length: 8790, dtype: object>

# %%
 ratings=data['rating'].value_counts().reset_index().sort_values(by='count',
 ascending=False)
 plt.bar(ratings['rating'], ratings['count'])
 plt.xticks(rotation=45, ha='right')
 plt.xlabel("Rating Types")
 plt.ylabel("Rating Frequency")
 plt.suptitle('Rating on Netflix', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Rating on Netflix')

# %%
plt.pie(ratings['count'][:8], labels=ratings['rating'][:8], autopct='%.0f%%')
plt.suptitle('Rating on Netflix', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Rating on Netflix')

# %%
 top_ten_countries=data['country'].value_counts().reset_index().sort_values(by='count', ascending=False)[:10]
 plt.figure(figsize=(10, 6))
 plt.bar(top_ten_countries['country'], top_ten_countries['count'])
 plt.xticks(rotation=45, ha='right')
 plt.xlabel("Country")
 plt.ylabel("Frequency")
 plt.suptitle("Top 10 countries with most content on Netflix")
 plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=data,x='rating',hue='release_year')
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
